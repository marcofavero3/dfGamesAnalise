# %% [markdown]
# <a href="https://colab.research.google.com/github/marcofavero3/dfGamesAnalise/blob/main/Projeto_GamesKaggle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import warnings

warnings.filterwarnings('ignore')

url = 'https://raw.githubusercontent.com/marcofavero3/dfGamesAnalise/main/PS4_GamesSales.csv'

df = pd.read_csv(url, encoding='ISO-8859-1') #necessário adicionar o encoding para aceitar a leitura, visto que não possui a formatação correta

df.head()
# Out:
#                         Game    Year             Genre       Publisher  \
# 0         Grand Theft Auto V  2014.0            Action  Rockstar Games
# 1  Call of Duty: Black Ops 3  2015.0           Shooter      Activision
# 2      Red Dead Redemption 2  2018.0  Action-Adventure  Rockstar Games
# 3         Call of Duty: WWII  2017.0           Shooter      Activision
# 4                    FIFA 18  2017.0            Sports       EA Sports
#
#    North America  Europe  Japan  Rest of World  Global
# 0           6.06    9.71   0.60           3.02   19.39
# 1           6.18    6.05   0.41           2.44   15.09
# 2           5.26    6.21   0.21           2.26   13.94
# 3           4.67    6.21   0.40           2.12   13.40
# 4           1.27    8.64   0.15           1.73   11.80

# %%
#analisar a dimensão

df.shape
# Out:
# (1034, 9)

# %%
#verificar os nulos

df.isnull().sum()
# Out:
# Game               0
# Year             209
# Genre              0
# Publisher        209
# North America      0
# Europe             0
# Japan              0
# Rest of World      0
# Global             0
# dtype: int64

# %%
#grafico dos nulos

plt.figure(figsize=(14,6))
plt.title('Verificando campos nulos')

sns.heatmap(df.isnull(), cbar=False);

# %%
#Remover valores nulos

df.dropna( inplace=True) #comando inplace ele sobrescreve o DF

# %%
#Ver estatisticas
df.describe()
# Out:
#               Year  North America      Europe       Japan  Rest of World  \
# count   825.000000     825.000000  825.000000  825.000000     825.000000
# mean   2015.966061       0.256448    0.311600    0.042048       0.111552
# std       1.298360       0.620259    0.868271    0.119814       0.274713
# min    2013.000000       0.000000    0.000000    0.000000       0.000000
# 25%    2015.000000       0.000000    0.000000    0.000000       0.000000
# 50%    2016.000000       0.050000    0.020000    0.000000       0.020000
# 75%    2017.000000       0.190000    0.220000    0.040000       0.090000
# max    2020.000000       6.180000    9.710000    2.170000       3.020000
#
#            Global
# count  825.000000
# mean     0.721721
# std      1.743122
# min      0.000000
# 25%      0.030000
# 50%      0.120000
# 75%      0.560000
# max     19.390000

# %%
sns.barplot(data=df, x='Year', y='Global', ci=None, estimator=sum)

# Adiciona o título do gráfico
plt.title('Vendas Globais em Milhões', loc='left', fontsize=14)

# Adiciona o rótulo do eixo y
plt.ylabel('Qnt de vendas')

# Exibe o gráfico
plt.show()

# %%
#Remover anos 2019 e 2020 e mostrar os anos que me "restaram"

df = df.loc[(df['Year'] !=2019) & (df['Year'] !=2020)] #['Year'].unique()

df.head()
# Out:
#                         Game    Year             Genre       Publisher  \
# 0         Grand Theft Auto V  2014.0            Action  Rockstar Games
# 1  Call of Duty: Black Ops 3  2015.0           Shooter      Activision
# 2      Red Dead Redemption 2  2018.0  Action-Adventure  Rockstar Games
# 3         Call of Duty: WWII  2017.0           Shooter      Activision
# 4                    FIFA 18  2017.0            Sports       EA Sports
#
#    North America  Europe  Japan  Rest of World  Global
# 0           6.06    9.71   0.60           3.02   19.39
# 1           6.18    6.05   0.41           2.44   15.09
# 2           5.26    6.21   0.21           2.26   13.94
# 3           4.67    6.21   0.40           2.12   13.40
# 4           1.27    8.64   0.15           1.73   11.80

# %%
#Plotar a distruição do valor GLOBAL

#TAMANHO
plt.figure(figsize=(12,5))

#ESTILO
plt.style.use('ggplot')

#PLOTAGEM
plt.title('Distribuição das vendas Globais', loc='left', fontsize=14) #titulo
sns.kdeplot(df['Global'], shade=True, bw=1, linewidth=2.5) #shade e bw são comandos para passar a transparencia/sombreamento da curva do gráfico
# Out:
# <Axes: title={'left': 'Distribuição das vendas Globais'}, xlabel='Global', ylabel='Density'>

# %%
#Verificar a distribuição por ano/local
df.groupby(by=['Year']).sum()
# Out:
#         North America  Europe  Japan  Rest of World  Global
# Year
# 2013.0          10.35   12.88   0.97           4.57   28.76
# 2014.0          39.80   54.12   3.58          18.29  115.85
# 2015.0          49.60   56.21   7.28          20.88  133.99
# 2016.0          47.40   57.98   9.65          20.71  135.72
# 2017.0          44.77   57.18   9.08          19.89  130.90
# 2018.0          19.65   18.70   4.13           7.69   50.20

# %%
#PLOTAGEM
plt.figure(figsize=(10,4))
plt.title('Distribuição Global')

sns.boxplot(data=df, x='Year', y='Global');

# %%
#Criando uma base de corte de jogos com mais de 10 milhões de vendas

df.loc[df['Global'] >=10]
# Out:
#                         Game    Year             Genre  \
# 0         Grand Theft Auto V  2014.0            Action
# 1  Call of Duty: Black Ops 3  2015.0           Shooter
# 2      Red Dead Redemption 2  2018.0  Action-Adventure
# 3         Call of Duty: WWII  2017.0           Shooter
# 4                    FIFA 18  2017.0            Sports
# 5                    FIFA 17  2016.0            Sports
# 6            Uncharted (PS4)  2016.0            Action
#
#                         Publisher  North America  Europe  Japan  \
# 0                  Rockstar Games           6.06    9.71   0.60
# 1                      Activision           6.18    6.05   0.41
# 2                  Rockstar Games           5.26    6.21   0.21
# 3                      Activision           4.67    6.21   0.40
# 4                       EA Sports           1.27    8.64   0.15
# 5                 Electronic Arts           1.26    7.95   0.12
# 6  Sony Interactive Entertainment           4.49    3.93   0.21
#
# ...

# %%
df
# Out:
#                            Game    Year             Genre  \
# 0            Grand Theft Auto V  2014.0            Action
# 1     Call of Duty: Black Ops 3  2015.0           Shooter
# 2         Red Dead Redemption 2  2018.0  Action-Adventure
# 3            Call of Duty: WWII  2017.0           Shooter
# 4                       FIFA 18  2017.0            Sports
# ...                         ...     ...               ...
# 1024                  Biomutant  2018.0            Action
# 1026                    de Blob  2017.0          Platform
# 1027           Chaos on Deponia  2017.0         Adventure
# 1028                  Code Vein  2018.0            Action
# 1030   Radial G Racing Revolved  2017.0            Racing
#
#                        Publisher  North America  Europe  Japan  Rest of World  \
# 0                 Rockstar Games           6.06    9.71   0.60           3.02
# 1                     Activision           6.18    6.05   0.41           2.44
# ...

# %%
Analise = df.groupby( by=['Year'] ).sum().reset_index()

# analisando a proporção dos 100% de cada continemente comparado ao Total
America = [ America / Total * 100 for America, Total in zip( Analise['North America'], Analise['Global'] ) ]
Europa = [ Europa / Total * 100 for Europa, Total in zip( Analise['Europe'], Analise['Global'] ) ]
Japao = [ Japao / Total * 100 for Japao, Total in zip( Analise['Japan'], Analise['Global'] ) ]
Mundo = [ Mundo / Total * 100 for Mundo, Total in zip( Analise['Rest of World'], Analise['Global'] ) ]

America, Europa, Japao, Mundo
# Out:
# ([35.9874826147427,
#   34.35476909797151,
#   37.01768788715576,
#   34.92484526967286,
#   34.20168067226891,
#   39.14342629482071],
#  [44.78442280945759,
#   46.71558049201555,
#   41.95089185760131,
#   42.72030651340996,
#   43.68220015278838,
#   37.25099601593625],
#  [3.372739916550765,
#   3.0902028485110056,
#   5.433241286663184,
#   7.110226937813145,
#   6.936592818945759,
#   8.227091633466136],
#  [15.890125173852576,
#   15.78765645230902,
#   15.58325248152847,
#   15.259357500736812,
#   15.194805194805195,
#   15.31872509960159])

# %%
#Plotar grafico de barras empilhado

plt.figure(figsize=(10,5))

#config do grafico
Largura_Barra = 0.85
Rotulos = Analise['Year']
Grupos = [0,1,2,3,4,5]
#titulo
plt.title('Analise da distribuição por continentes')

#plot america
plt.bar( Grupos, America, width=Largura_Barra, color='#b5ffb9', edgecolor='white') #VERDE
#plot europa
plt.bar( Grupos, Europa, bottom=America, width=Largura_Barra, color='#f9bc86', edgecolor='white') #LARANJA
#plot japao
plt.bar( Grupos, Japao, bottom=[A+B for A,B in zip(America,Europa)], width=Largura_Barra, color='#a3acff', edgecolor='white')#AZUL
#plot resto do mundo
plt.bar( Grupos, Mundo, bottom=[A+B+C for A,B,C in zip(America,Europa,Japao)], width=Largura_Barra, color='#d3acfe', edgecolor='white')

#Labels
plt.xticks(Grupos, Rotulos)
plt.xlabel('Grupo')
plt.ylabel('Distribuição %')

#Legenda
plt.legend(['America Norte','Europa','Japao','Mundo'], loc='upper left', bbox_to_anchor=(0.15,-0.1), ncol=4);

# %%
df.head()
# Out:
#                         Game    Year             Genre       Publisher  \
# 0         Grand Theft Auto V  2014.0            Action  Rockstar Games
# 1  Call of Duty: Black Ops 3  2015.0           Shooter      Activision
# 2      Red Dead Redemption 2  2018.0  Action-Adventure  Rockstar Games
# 3         Call of Duty: WWII  2017.0           Shooter      Activision
# 4                    FIFA 18  2017.0            Sports       EA Sports
#
#    North America  Europe  Japan  Rest of World  Global
# 0           6.06    9.71   0.60           3.02   19.39
# 1           6.18    6.05   0.41           2.44   15.09
# 2           5.26    6.21   0.21           2.26   13.94
# 3           4.67    6.21   0.40           2.12   13.40
# 4           1.27    8.64   0.15           1.73   11.80

# %%
#Verificando a empresa que publicou o game
df['Publisher'].unique()
# Out:
# array(['Rockstar Games', 'Activision', 'EA Sports', 'Electronic Arts',
#        'Sony Interactive Entertainment', 'Bethesda Softworks',
#        'Sony Computer Entertainment', 'Namco Bandai Games', 'Square Enix',
#        'Capcom', 'Blizzard Entertainment', 'Ubisoft',
#        'Warner Bros. Interactive', '2K Sports',
#        'Warner Bros. Interactive Entertainment',
#        'Konami Digital Entertainment', '2K Games', 'Hello Games',
#        '505 Games', 'Deep Silver', 'Take-Two Interactive',
#        'Bandai Namco Games', 'Sega', 'Tecmo Koei', 'Gearbox Software',
#        'Mojang', 'Disney Interactive Studios', 'Focus Home Interactive',
#        'Studio Wildcard', 'Codemasters', 'Koch Media',
#        'Harmonix Music Systems', 'Rebellion Developments', 'Gun Media',
#        'Telltale Games', 'Kalypso Media', 'City Interactive',
#        'NIS America', 'Sold Out', 'Tripwire Interactive', 'PQube',
#        'THQ Nordic', 'Milestone S.r.l.', 'Nordic Games', 'Astragon',
# ...

# %%
#verificando um plot com todos Publishers (100% poluído e impossível de verificar)


sns.boxplot(data=df, x='Publisher', y='Global')
# Out:
# <Axes: xlabel='Publisher', ylabel='Global'>

# %%
#CONVERSÃO DE VALORES PARA NÚMEROS, E ATRIBUIÇÃO DE COLUNAS, FIZ A ALTERAÇÃO DE VALORES NUMERICOS TROCANDO PELOS NOMES, DESSA FORMA FICANDO MAIS LEGIVEL
from sklearn.preprocessing import LabelEncoder
Funcao_Label = LabelEncoder()

df['Produtor'] = Funcao_Label.fit_transform(df['Publisher'])
df['Genero'] = Funcao_Label.fit_transform(df['Genre'])
df['Jogo'] = Funcao_Label.fit_transform(df['Game'])

df.head()
# Out:
#                         Game    Year             Genre       Publisher  \
# 0         Grand Theft Auto V  2014.0            Action  Rockstar Games
# 1  Call of Duty: Black Ops 3  2015.0           Shooter      Activision
# 2      Red Dead Redemption 2  2018.0  Action-Adventure  Rockstar Games
# 3         Call of Duty: WWII  2017.0           Shooter      Activision
# 4                    FIFA 18  2017.0            Sports       EA Sports
#
#    North America  Europe  Japan  Rest of World  Global  Produtor  Genero  Jogo
# 0           6.06    9.71   0.60           3.02   19.39       107       0   273
# 1           6.18    6.05   0.41           2.44   15.09         8      12    98
# 2           5.26    6.21   0.21           2.26   13.94       107       1   521
# 3           4.67    6.21   0.40           2.12   13.40         8      12   102
# 4           1.27    8.64   0.15           1.73   11.80        40      14   222

# %%
#Paleta de Cores
Paleta_Cores = sns.color_palette('husl',8)
Paleta_Cores
# Out:
# [(0.9677975592919913, 0.44127456009157356, 0.5358103155058701),
#  (0.8087954113106306, 0.5634700050056693, 0.19502642696727285),
#  (0.5920891529639701, 0.6418467016378244, 0.1935069134991043),
#  (0.19783576093349015, 0.6955516966063037, 0.3995301037444499),
#  (0.21044753832183283, 0.6773105080456748, 0.6433941168468681),
#  (0.22335772267769388, 0.6565792317435265, 0.8171355503265633),
#  (0.6423044349219739, 0.5497680051256467, 0.9582651433656727),
#  (0.9603888539940703, 0.3814317878772117, 0.8683117650835491)]

# %%
#PLOTAGEM DAS PRODUTORAS DE GAMES
plt.figure(figsize=(20,5))
plt.title('Analise dos Produtores de Games')

sns.scatterplot(data=df, x='Produtor', y='Global', color=Paleta_Cores[0])
# Out:
# <Axes: title={'center': 'Analise dos Produtores de Games'}, xlabel='Produtor', ylabel='Global'>

# %%
#PLOTAGEM DO GENERO DOS GAMES

plt.figure(figsize=(20,5))
plt.title('Analise dos Generos dos Games')

sns.scatterplot(data=df, x='Genero', y='Global', color=Paleta_Cores[1])
# Out:
# <Axes: title={'center': 'Analise dos Generos dos Games'}, xlabel='Genero', ylabel='Global'>

# %%
# PLOTAGEM DOS GAMES


plt.figure(figsize=(20,5))
plt.title('Analise dos Games')

sns.scatterplot(data=df, x='Jogo', y='Global', color=Paleta_Cores[2])
# Out:
# <Axes: title={'center': 'Analise dos Games'}, xlabel='Jogo', ylabel='Global'>

# %%
# Relatorio --> Report dos dados, interpretação dos gráficos

# Tamanho da Imagem
fig, ax = plt.subplots( figsize=(18, 15) )

# Cor de fundo
Cor_Fundo = '#f5f5f5'
ax.set_facecolor( Cor_Fundo )
fig.set_facecolor( Cor_Fundo )

# Estilo dos gráficos
plt.style.use('seaborn')

# Titulo da figura
plt.suptitle('Analise do Grafico de Vendas de Jogos', fontsize=22, color='#404040', fontweight=600 )

# Parametros para o grid
Linhas = 3
Colunas = 2

# Acessando gráfico 1
plt.subplot( Linhas, Colunas, 1)
# Titulo
plt.title('Quantidade de Vendas Globais (mi)', loc='left', fontsize=14 )
# Grafico
plt.bar( df['Year'], df['Global'], color='#69b3a2' )
# Label
plt.ylabel('Quantidade Vendas (mi)')


# Acessando gráfico 2
plt.subplot( Linhas, Colunas, 2)
# titulo
plt.title('Análise da distribuição Global (mi)')
# Plot
sns.boxplot( data=df, x='Year', y='Global')


# Acessando gráfico 3
plt.subplot( Linhas, Colunas, 3)
# LArgura barra no gráfico
Largura_Barra = 0.85
Rotulos = Analise['Year']
Grupos = [0, 1, 2, 3, 4, 5]
# titulo
plt.title('Análise distribuição por continentes', loc='left', fontsize=14)
# Plot da America
plt.bar( Grupos, America, width=Largura_Barra, color='#b5ffb9', edgecolor='white' )
# Plot da Europa
plt.bar( Grupos, Europa, bottom=America, width=Largura_Barra, color='#f9bc86', edgecolor='white' )
# Plot do Japao
plt.bar( Grupos, Japao, bottom=[ A + B for A, B in zip(America, Europa) ], width=Largura_Barra, color='#a3acff', edgecolor='white' )
# Plot do Resto do mundo
plt.bar( Grupos, Mundo, bottom=[ A + B + C for A, B, C in zip(America, Europa, Japao) ], width=Largura_Barra, color='#d3acfe', edgecolor='white' )
# Labels
plt.xticks( Grupos, Rotulos )
plt.xlabel('Grupo')
plt.ylabel('Distribuição %')
# Legenda
plt.legend( ['America N', 'Europa',' Japão', 'Mundo'], loc='upper left', bbox_to_anchor=(0.15, -0.1), ncol=4 );


# Acessando gráfico 4
plt.subplot( Linhas, Colunas, 4)
plt.title('Análise dos produtores de Game (mi)', loc='left', fontsize=14 )
sns.scatterplot(data=df, x='Produtor', y='Global', color=Paleta_Cores[0] );


# Acessando gráfico 5
plt.subplot( Linhas, Colunas, 5)
plt.title('Análise dos generos do Game (mi)', loc='left', fontsize=14)
sns.scatterplot(data=df, x='Genero', y='Global', color=Paleta_Cores[0] );


# Acessando gráfico 6
plt.subplot( Linhas, Colunas, 6)
plt.title('Análise dos Games (mi)', loc='left', fontsize=14)
sns.scatterplot(data=df, x='Jogo', y='Global', color=Paleta_Cores[0] );


# Ajustar o layout
plt.subplots_adjust( hspace=0.35, wspace=0.15 )

# Rodapé
Rodape = '''
Essse relatório foi elaborado no treinado "Python para Análise de Dados"
'''

# Incluindo o rodape no relatorio
fig.text( 0.5, -0.02, Rodape, ha='center', va='bottom', size=12, color='#938ca1');
